# %% [markdown]
# # Introduction

# %% [markdown]
# sup boi!!

# %% [markdown]
# Right now, this notebook is not connected to the code defining the manuscript object. We access it with the following import statement.

# %%
from digital_manuscript import BnF

# %% [markdown]
# BnF is the name of a <b>class</b>, or plans for creating a specific collection of data, called an <b>instance</b> or <b>object</b>.

# %%
manuscript = BnF() # create an instance of the BnF() class named 'manuscript'

# %% [markdown]
# The Manuscipt Object is a container, meaning it stores and catalogues other Python objects. In this case, the objects within the container represent individual entries separated by div tags. The entries are indentified, or indexed, by their div id. We can use the div id to retrieve the entry object from the manuscript.

# %%
sword_varnish = manuscript.entry('004v_1')

# %% [markdown]
# The entry objects have encoded features, or <b>attributes</b> of their own. Given any entry object, we can, for example, recover its div id.

# %%
sword_varnish.identity
# Out:
# '004v_1'

# %% [markdown]
# ## Entry Attributes

# %%
sword_varnish.get_title('tl')
# Out:
# 'Black varnish for sword guard, bands for trunks, &amp;c'

# %% [markdown]
# The entry class has a built in `.text()` function to retrieve the text. There are two <b>parameters</b> for this retreival, the version of the manuscript (tc, tcn, or tl), and whether or not to include the XML tags. The manuscript version must be specified, but if the XML parameter is left blank, it defaults to removing the XML.

# %%
sword_varnish.text('tl')
# Out:
# 'Black varnish for sword guard, bands for trunks,\n&amp;c\n\nTake linseed oil or more cheaply, walnut\noil, and rid it of grease with garlic &amp;\nonions +hog’s\nfennel, some also add bread crusts, which you will\nboil in it for a good quarter of an hour. Next, put\nin one lb of the oil thus boiled the size of a walnut of black\npitch &amp; a double handful of grains of wheat, without\nremoving the garlic &amp; onions, and let\nit boil together for a good quarter of an hour. And\nwhen the pitch is well melted &amp; when the oil has body,\nyou can remove it from the fire. Then, to varnish, place your\niron over a low charcoal fire &amp; apply your\nvarnish with a feather or a brush.\nAnd when you see that it no longer smokes, it is done and your\nvarnish is dry.\n\n\n\nFor excellent black varnish, add two or three paternoster\nbeads of jet among the rest.\n\n\n\nSome consider walnut oil better.\n\n\n\nIf there is a lot of varnish, it needs to boil for at least\nhalf a day, for it is better the more it boils. It\nis dangerous if it catches fire, if it goes over the top, and is\nhard to extinguish. Make this therefore in a courtyard or an\nopen space.\n\n \n\nIn five or six lb of oil, one must put one lb\nof galipot, which costs 4 sous, &amp; some\npeeled garlic cloves. This varnish in and of\nitself is not black, but it blackens over the fire.\n\n\n\nSee below, around the 3rd part of this book,\nafter sands, in the chapter on furbishers.'

# %%
sword_varnish.text('tc', xml=True)
# Out:
# '<div id="p004v_1" categories="varnish;arms and armor">\n\n<head><m>Vernis noir</m> pour garde<lb/>\n\ndespee bandes de bahus &amp;</head>\n\n<ab>Prens <m>huile de <pa>lin</pa></m> ou pour meilleur marche de\nl<m>huile<lb/>\n\nde <pa>noix</pa></m> Et la fais desgraisser avecq des\n<m><pa>aulx</pa></m> &amp; <del><m><pa>oigno<exp>n</exp>s</pa></m></del>\n<add><mark>+</mark><m><pa>queues de pourrceaulx</pa></m><lb/>\n\naulcuns adjoustent des <m>crostes de\npain</m></add><lb/>\n\nque tu feras bouillir dedans <ms><tmp>un bon quart\ndheure</tmp></ms><lb/>\n\nApres mects dans une <ms>lb</ms> d<m>huile</m> ainsy bouilly <ms>la\ngrosseur<lb/>\n\ndune <pa>noix</pa></ms> de <m>poix noire</m> &amp; une <ms><bp>joinctee</bp></ms>\nde <m><pa>bled de froment</pa></m><lb/>\n\nsans oster les <m><pa>aulx</pa></m> &amp; <m><pa>oignons</pa></m> Et\nlaisser bouillir ensemble<lb/>\n\n<ms><tmp>un bon quart dheure</tmp></ms> Et quand la <m>poix</m> est bien\nfondue<lb/>\n\n&amp; que l<m>huile</m> a corps Tu le peulx tirer du foeu Puys<lb/>\n\npour vernir mects ton <m>fer</m> sur le foeu legier de\n<m>charbons</m><lb/>\n\n&amp; aplique avecques une <tl>plume</tl> ou <tl>broisse</tl> ton\n<m>vernis</m> Et<lb/>\n\nquand tu verras quil ne <m>fumera</m> plus cest faict et ton<lb/>\n\n<m>vernis</m> est sec</ab>\n\n<ab margin="left-middle">\n\nPour excellent <m>vernis<lb/>\n\nnoir</m> mects deulx ou <lb/>\n\ntrois <ms>patenostres</ms> de<lb/>\n\n<m>geyct</m> parmy le reste</ab>\n\n<ab margin="left-middle">\n\nAulcuns estiment l<m>huile<lb/>\n\nde <pa>noix</pa></m> meilleur</ab>\n\n<ab margin="left-middle">\n\nSil y a quantite de<lb/>\n\n<m>vernis</m> il fault bien<lb/>\n\nquil bouille <ms><tmp>un demy<lb/>\n\njour</tmp></ms>Car il est<lb/>\n\nmeilleur tant plus il<lb/>\n\nboult Il est dangereux<lb/>\n\nque le feu sy mecte<lb/>\n\nsil sen va par<lb/>\n\ndessus et est malaise<lb/>\n\ndestaindre Fais<lb/>\n\nle doncq dans une <lb/>\n\n<env>basse court</env> ou <env>lieu<lb/>\n\ndescouvert</env></ab>\n\n<ab margin="left-middle" render="tall">\n\nEn cinq ou six <ms>lb</ms> d<m>huile</m><lb/>\n\non mect une <ms>lb</ms> de <m>Galipot</m><lb/>\n\nqui coste 4 <cn>s<exp>ols</exp></cn> &amp; des <m>gousses<lb/>\n\nd<pa>ail</pa> pelees</m> Ce <m>vernis</m><lb/>\n\nde soymesme nest pas<lb/>\n\nnoir Mays il se<lb/>\n\nnoircist au foeu</ab>\n\n<ab margin="left-middle" render="tall">\n\n\nVoy cy apres<lb/>\n\nvers la 3 partye<lb/>\n\nde ce livre apres les<lb/>\n\n<m>sables</m> au chapitre<lb/>\n\ndu <pro>fourbisseur</pro><comment rid="c_004v_01"/></ab>\n\n</div>'

# %% [markdown]
# Properties are XML tagged data manually added to the manuscript. The `.prop()` function retrieves this data and takes two parameters, the property type and the version of the manuscript. The full list of properties and the syntax for retrieving the properities are shown below.

# %%
sword_varnish_materials = sword_varnish.get_prop('material', 'tl')
sword_varnish_materials
# Out:
# ['clofe',
#  'hog’s fennel',
#  'pitch',
#  'grain',
#  'onion',
#  'sand',
#  'oil',
#  'iron',
#  'garlic',
#  'galipot',
#  'jet',
#  'smoke',
#  'bread crust',
#  'varnish',
#  'charcoal']

# %%
sword_varnish_plants = sword_varnish.get_prop('plant', 'tcn')
sword_varnish_plants
# Out:
# ['queues de pourrceaulx',
#  'oignons',
#  'aulx',
#  'bled de froment',
#  'noix',
#  'ail',
#  'lin']

# %% [markdown]
# ## Manuscript Attributes

# %% [markdown]
# The property attribute of the entries can be used to group entries with similar properties. The `.search` function for the BnF() class can be used for this purpose with varying degrees of specification. First, we can simply specify whether or not a property appears in a manuscript. We can apply as many properties as we care to specify to the search, and if none are specified the entire manuscript will be returned.

# %%
has_materials = manuscript.search(material=True)
has_materials
# Out:
# ['001r_1',
#  '001v_1',
#  '002r_2',
#  '002v_2',
#  '002v_3',
#  '003r_1',
#  '003r_2',
#  '003r_3',
#  '003v_1',
#  '004r_1',
#  '004r_2',
#  '004v_1',
#  '004v_2',
#  '004v_3',
#  '005r_1',
#  '005r_2',
#  '005v_1',
#  '006r_1',
#  '006v_1',
#  '006v_2',
#  '007r_1',
#  '007r_2',
#  '007r_3',
#  '007r_4',
#  '007v_1',
#  '007v_2',
#  '007v_3',
#  '007v_4',
#  '008r_1',
#  '008r_2',
#  '008r_3',
#  '008r_4',
#  '008v_1',
#  '008v_2',
#  '008v_3',
#  '008v_4',
#  '008v_5',
#  '009r_1',
#  '009v_1',
#  '009v_3',
#  '010r_1',
#  '010r_2',
#  '010r_3',
#  '010r_4',
#  '010r_5',
#  '010v_1',
#  '010v_2',
#  '010v_3',
#  '010v_4',
#  '011r_1',
#  '011v_1',
#  '011v_2',
#  '011v_3',
#  '011v_4',
#  '011v_5',
#  '012r_1',
#  '012r_2',
#  '012r_3',
#  '012r_4',
#  '012v_1',
#  '012v_2',
#  '012v_3',
#  '013r_1',
#  '013r_2',
#  '013r_3',
#  '013r_4',
#  '013v_1',
#  '013v_2',
#  '013v_3',
#  '013v_5',
#  '014r_1',
#  '015r_1',
#  '015r_2',
#  '015r_3',
#  '015v_1',
#  '015v_2',
#  '015v_3',
#  '015v_4',
#  '015v_5',
#  '015v_6',
#  '016r_1',
#  '016v_1',
#  '016v_2',
#  '016v_3',
#  '016v_4',
#  '016v_5',
#  '017r_1',
#  '019v_1',
#  '019v_2',
#  '019v_3',
#  '020r_1',
#  '020r_2',
#  '020v_1',
#  '020v_2',
#  '020v_4',
#  '020v_6',
#  '021r_1',
#  '021r_2',
#  '021v_1',
#  '021v_2',
#  '022v_1',
#  '023r_1',
#  '023v_1',
#  '024r_1',
#  '024v_1',
#  '024v_2',
#  '024v_3',
#  '025v_1',
#  '026r_2',
#  '028v_1',
#  '029r_1',
#  '029v_1',
#  '029v_2',
#  '029v_3',
#  '029v_4',
#  '029v_5',
#  '029v_6',
#  '030r_1',
#  '030r_2',
#  '031r_1',
#  '031r_2',
#  '031r_3',
#  '031r_4',
#  '031v_1',
#  '031v_2',
#  '031v_4',
#  '032r_2',
#  '032r_3',
#  '032v_1',
#  '032v_2',
#  '032v_3',
#  '033r_1',
#  '033r_2',
#  '033v_1',
#  '033v_2',
#  '034r_4',
#  '034r_5',
#  '034v_1',
#  '035r_2',
#  '035r_3',
#  '035r_4',
#  '035v_1',
#  '035v_2',
#  '036r_1',
#  '036v_1',
#  '036v_3',
#  '037r_1',
#  '037r_2',
#  '037r_3',
#  '037r_4',
#  '037v_1',
#  '037v_2',
#  '037v_3',
#  '038r_1',
#  '038r_2',
#  '038r_3',
#  '038r_4',
#  '038v_1',
#  '038v_2',
#  '038v_5',
#  '038v_6',
#  '039r_1',
#  '039r_2',
#  '039v_1',
#  '039v_2',
#  '039v_3',
#  '040r_1',
#  '040r_2',
#  '040r_3',
#  '040r_4',
#  '040r_5',
#  '040v_1',
#  '040v_2',
#  '040v_3',
#  '040v_4',
#  '041r_03',
#  '041r_04',
#  '041r_1',
#  '041v_1',
#  '041v_2',
#  '041v_3',
#  '042r_1',
#  '042r_2',
#  '042r_3',
#  '042v_1',
#  '042v_2',
#  '042v_3',
#  '042v_4',
#  '042v_5',
#  '042v_6',
#  '043r_2',
#  '043r_3',
#  '043r_4',
#  '043v_1',
#  '043v_2',
#  '043v_3',
#  '043v_4',
#  '044r_1',
#  '044r_2',
#  '044r_3',
#  '044r_4',
#  '044r_5',
#  '044v_1',
#  '044v_2',
#  '044v_3',
#  '044v_4',
#  '045r_1',
#  '045v_1',
#  '045v_2',
#  '046r_1',
#  '046r_2',
#  '046r_3',
#  '046r_4',
#  '046v_1',
#  '046v_2',
#  '046v_3',
#  '046v_4',
#  '046v_5',
#  '046v_6',
#  '046v_7',
#  '047r_1',
#  '047r_2',
#  '047r_3',
#  '047r_4',
#  '047r_5',
#  '047v_1',
#  '047v_2',
#  '047v_3',
#  '047v_4',
#  '048r_1',
#  '048r_2',
#  '048r_3',
#  '048r_4',
#  '048v_1',
#  '048v_2',
#  '049r_1',
#  '049r_2',
#  '049r_3',
#  '049r_4',
#  '049v_1',
#  '049v_2',
#  '050r_1',
#  '050r_2',
#  '050v_1',
#  '050v_2',
#  '051r_1',
#  '051r_2',
#  '052r_1',
#  '052v_2',
#  '053r_1',
#  '053r_2',
#  '053r_3',
#  '053r_4',
#  '053r_6',
#  '053v_1',
#  '054v_2',
#  '054v_3',
#  '054v_4',
#  '054v_5',
#  '055r_1',
#  '055r_2',
#  '055r_3',
#  '055r_4',
#  '055v_1',
#  '055v_2',
#  '055v_3',
#  '055v_4',
#  '056r_1',
#  '056r_2',
#  '056v_1',
#  '057v_1',
#  '057v_2',
#  '058v_1',
#  '058v_3',
#  '058v_4',
#  '058v_5',
#  '059r_1',
#  '059r_2',
#  '059v_1',
#  '059v_2',
#  '059v_3',
#  '059v_4',
#  '059v_5',
#  '059v_6',
#  '060r_1',
#  '060r_3',
#  '060v_1',
#  '060v_2',
#  '060v_3',
#  '060v_4',
#  '060v_5',
#  '061r_1',
#  '061r_3',
#  '061v_1',
#  '061v_2',
#  '061v_3',
#  '061v_4',
#  '062r_1',
#  '062r_2',
#  '062r_3',
#  '062r_4',
#  '062v_1',
#  '062v_2',
#  '062v_3',
#  '063r_1',
#  '063r_2',
#  '063r_3',
#  '063r_4',
#  '063r_5',
#  '063r_6',
#  '063v_1',
#  '063v_2',
#  '063v_3',
#  '063v_4',
#  '063v_5',
#  '063v_6',
#  '063v_7',
#  '064r_2',
#  '064r_3',
#  '064r_4',
#  '064r_5',
#  '064r_6',
#  '064r_7',
#  '064v_1',
#  '064v_3',
#  '064v_5',
#  '065r_1',
#  '065r_3',
#  '065r_4',
#  '065v_1',
#  '065v_2',
#  '065v_3',
#  '065v_5',
#  '065v_6',
#  '065v_7',
#  '066r_2',
#  '066r_3',
#  '066r_4',
#  '066r_5',
#  '066r_6',
#  '066v_1',
#  '066v_2',
#  '066v_3',
#  '066v_4',
#  '067r_1',
#  '067r_2',
#  '067r_3',
#  '067r_4',
#  '067v_1',
#  '067v_2',
#  '067v_3',
#  '068r_1',
#  '068r_2',
#  '068r_3',
#  '069r_2',
#  '071r_1',
#  '071r_2',
#  '071r_3',
#  '071r_4',
#  '071r_5',
#  '071v_1',
#  '071v_3',
#  '071v_4',
#  '072r_1',
#  '072r_2',
#  '072v_1',
#  '073r_1',
#  '073r_2',
#  '073r_3',
#  '073r_4',
#  '073r_5',
#  '073v_1',
#  '073v_2',
#  '073v_3',
#  '073v_4',
#  '074r_1',
#  '074r_2',
#  '074r_3',
#  '074v_1',
#  '074v_2',
#  '074v_3',
#  '074v_4',
#  '075r_1',
#  '075r_2',
#  '075r_3',
#  '075r_4',
#  '075r_5',
#  '075v_1',
#  '075v_2',
#  '075v_3',
#  '075v_4',
#  '076r_1',
#  '076r_2',
#  '076r_3',
#  '076r_4',
#  '076r_5',
#  '076v_1',
#  '076v_2',
#  '076v_3',
#  '076v_4',
#  '077r_1',
#  '077r_2',
#  '077r_3',
#  '077r_4',
#  '077v_1',
#  '077v_2',
#  '077v_3',
#  '078r_1',
#  '078r_2',
#  '078r_3',
#  '078v_1',
#  '078v_2',
#  '078v_3',
#  '078v_4',
#  '079r_1',
#  '079r_2',
#  '079r_3',
#  '079v_1',
#  '079v_2',
#  '079v_3',
#  '079v_4',
#  '080r_1',
#  '080r_2',
#  '080r_3',
#  '080v_1',
#  '081r_1',
#  '081r_2',
#  '081r_3',
#  '081r_4',
#  '081v_1',
#  '081v_2',
#  '081v_3',
#  '081v_4',
#  '082r_1',
#  '082r_2',
#  '082r_3',
#  '082r_4',
#  '082v_1',
#  '082v_2',
#  '082v_3',
#  '082v_4',
#  '083r_1',
#  '083r_2',
#  '083r_3',
#  '083r_4',
#  '083r_5',
#  '083r_6',
#  '083v_1',
#  '083v_2',
#  '083v_3',
#  '084r_1',
#  '084r_3',
#  '084r_4',
#  '084r_5',
#  '084v_1',
#  '084v_2',
#  '084v_3',
#  '084v_4',
#  '085r_1',
#  '085r_2',
#  '085v_1',
#  '085v_2',
#  '085v_3',
#  '085v_4',
#  '086v_1',
#  '087r_1',
#  '087v_1',
#  '087v_2',
#  '087v_3',
#  '088r_2',
#  '088r_3',
#  '088r_5',
#  '088r_6',
#  '088v_1',
#  '088v_2',
#  '089r_1',
#  '089r_3',
#  '089v_1',
#  '089v_2',
#  '090r_1',
#  '090r_2',
#  '090r_3',
#  '090v_1',
#  '090v_2',
#  '091r_2',
#  '092r_1',
#  '092r_2',
#  '092r_3',
#  '092r_4',
#  '092v_1',
#  '092v_2',
#  '092v_3',
#  '093r_1',
#  '093r_4',
#  '093r_5',
#  '093v_1',
#  '093v_2',
#  '093v_3',
#  '094r_1',
#  '096v_1',
#  '096v_2',
#  '096v_3',
#  '097r_1',
#  '097r_2',
#  '097r_3',
#  '097v_1',
#  '098r_1',
#  '098r_2',
#  '098r_3',
#  '098v_2',
#  '098v_4',
#  '098v_5',
#  '099r_3',
#  '099v_2',
#  '099v_4',
#  '099v_5',
#  '099v_6',
#  '100r_1',
#  '100r_3',
#  '100r_4',
#  '100r_5',
#  '100v_1',
#  '100v_2',
#  '101r_1',
#  '101r_2',
#  '101v_1',
#  '101v_2',
#  '101v_3',
#  '101v_4',
#  '102r_1',
#  '102r_2',
#  '102r_3',
#  '102r_4',
#  '102v_1',
#  '102v_2',
#  '102v_3',
#  '103r_1',
#  '103r_2',
#  '103v_1',
#  '103v_2',
#  '103v_3',
#  '103v_4',
#  '103v_5',
#  '104r_1',
#  '104r_2',
#  '104r_3',
#  '104r_4',
#  '104r_5',
#  '104v_1',
#  '104v_2',
#  '104v_3',
#  '104v_4',
#  '105r_2',
#  '105r_3',
#  '105r_4',
#  '105v_2',
#  '105v_4',
#  '105v_5',
#  '106r_1',
#  '106r_2',
#  '106v_1',
#  '106v_2',
#  '106v_3',
#  '107r_1',
#  '108r_2',
#  '109r_1',
#  '109r_2',
#  '109r_3',
#  '109r_5',
#  '109v_1',
#  '109v_2',
#  '110r_2',
#  '110r_3',
#  '110v_1',
#  '110v_2',
#  '110v_3',
#  '111r_2',
#  '111r_3',
#  '111r_4',
#  '111r_5',
#  '111v_1',
#  '111v_2',
#  '111v_4',
#  '111v_5',
#  '112r_1',
#  '112r_2',
#  '112r_3',
#  '112r_4',
#  '112v_1',
#  '113r_1',
#  '114r_1',
#  '115r_1',
#  '115r_2',
#  '115v_1',
#  '115v_2',
#  '115v_3',
#  '116r_1',
#  '116r_2',
#  '116r_3',
#  '116r_4',
#  '116v_1',
#  '116v_2',
#  '116v_3',
#  '117r_1',
#  '117v_1',
#  '117v_2',
#  '117v_3',
#  '117v_4',
#  '117v_5',
#  '118r_1',
#  '118r_2',
#  '118r_3',
#  '118r_4',
#  '118r_5',
#  '118v_1',
#  '119r_1',
#  '119v_1',
#  '119v_2',
#  '120r_1',
#  '120r_2',
#  '120r_3',
#  '',
#  '120v_1',
#  '120v_2',
#  '120v_3',
#  '120v_6',
#  '121r_1',
#  '121v_1',
#  '121v_2',
#  '122r_1',
#  '122r_2',
#  '122v_1',
#  '122v_2',
#  '122v_3',
#  '123r_1',
#  '124r_1',
#  '124r_2',
#  '124r_3',
#  '124r_4',
#  '124v_1',
#  '124v_2',
#  '124v_3',
#  '125r_1',
#  '125r_2',
#  '125v_2',
#  '125v_3',
#  '126r_1',
#  '126v_1',
#  '126v_2',
#  '126v_3',
#  '127r_1',
#  '127v_1',
#  '128r_1',
#  '128v_1',
#  '129r_1',
#  '129r_2',
#  '129r_3',
#  '129r_4',
#  '129v_1',
#  '129v_2',
#  '129v_3',
#  '129v_4',
#  '130r_1',
#  '130r_2',
#  '130r_3',
#  '130r_4',
#  '130v_1',
#  '130v_3',
#  '131r_1',
#  '131r_2',
#  '131r_3',
#  '131r_4',
#  '131r_5',
#  '131v_1',
#  '132r_1',
#  '132r_2',
#  '132v_1',
#  '132v_2',
#  '132v_3',
#  '133r_1',
#  '133r_2',
#  '133r_3',
#  '133r_4',
#  '133v_1',
#  '133v_2',
#  '133v_3',
#  '134r_1',
#  '134r_2',
#  '134v_1',
#  '134v_2',
#  '134v_3',
#  '135r_1',
#  '135r_2',
#  '135r_3',
#  '135v_1',
#  '136r_1',
#  '136v_1',
#  '137r_1',
#  '137r_2',
#  '137r_3',
#  '137v_1',
#  '138v_1',
#  '138v_2',
#  '138v_3',
#  '139r_1',
#  '139v_1',
#  '140v_1',
#  '140v_2',
#  '140v_3',
#  '141r_1',
#  '142v_1',
#  '142v_3',
#  '143r_1',
#  '143r_2',
#  '143r_3',
#  '143v_1',
#  '143v_2',
#  '143v_3',
#  '144r_1',
#  '145r_1',
#  '145r_2',
#  '145v_1',
#  '145v_2',
#  '146v_1',
#  '147v_1',
#  '147v_2',
#  '147v_4',
#  '148r_1',
#  '148r_2',
#  '148r_4',
#  '148v_1',
#  '149r_1',
#  '149r_2',
#  '149r_3',
#  '149r_4',
#  '149v_1',
#  '149v_2',
#  '149v_3',
#  '149v_4',
#  '150r_1',
#  '150r_2',
#  '150r_3',
#  '150v_1',
#  '151v_1',
#  '152r_1',
#  '152v_1',
#  '153r_1',
#  '153r_2',
#  '153v_1',
#  '153v_2',
#  '154r_1',
#  '154r_2',
#  '154r_3',
#  '154r_4',
#  '154r_5',
#  '154v_1',
#  '154v_3',
#  '154v_4',
#  '154v_5',
#  '155r_1',
#  '155v_1',
#  '156r_1',
#  '156r_2',
#  '156r_3',
#  '156v_1',
#  '157r_1',
#  '157r_2',
#  '157r_3',
#  '157r_4',
#  '157r_5',
#  '157v_1',
#  '157v_2',
#  '157v_3',
#  '158r_1',
#  '158v_1',
#  '158v_2',
#  '158v_3',
#  '158v_4',
#  '159r_1',
#  '159r_3',
#  '159r_4',
#  '159v_1',
#  '159v_2',
#  '159v_4',
#  '160r_1',
#  '160r_2',
#  '160v_1',
#  '160v_2',
#  '160v_3',
#  '160v_4',
#  '160v_5',
#  '161r_1',
#  '161v_1',
#  '162r_2',
#  '162r_3',
#  '162v_2',
#  '162v_4',
#  '163r_1',
#  '163r_2',
#  '163v_1',
#  '163v_2',
#  '163v_3',
#  '164r_2',
#  '164r_3',
#  '164r_4',
#  '164v_1',
#  '164v_2',
#  '164v_3',
#  '165r_1',
#  '165r_2',
#  '165r_3',
#  '165r_4',
#  '165r_5',
#  '165r_6',
#  '165v_1',
#  '165v_2',
#  '165v_4',
#  '165v_5',
#  '165v_6',
#  '165v_7',
#  '166v_3',
#  '166v_4',
#  '166v_5',
#  '167r_1',
#  '169r_1',
#  '169v_1',
#  '169v_2',
#  '170r_1',
#  '170r_2',
#  '170r_4',
#  '170r_5',
#  '170r_6',
#  '170v_2',
#  '170v_3']

# %%
has_materials_plants = manuscript.search(material=True, plant=True)
has_materials_plants
# Out:
# ['001r_1',
#  '001v_1',
#  '002r_2',
#  '003r_1',
#  '004v_1',
#  '004v_2',
#  '004v_3',
#  '006r_1',
#  '006v_1',
#  '007r_2',
#  '007r_3',
#  '007v_2',
#  '008r_1',
#  '009r_1',
#  '010r_1',
#  '010r_3',
#  '012r_3',
#  '014r_1',
#  '015r_1',
#  '015v_6',
#  '016r_1',
#  '016v_1',
#  '016v_2',
#  '016v_4',
#  '016v_5',
#  '020r_1',
#  '020r_2',
#  '020v_1',
#  '020v_2',
#  '020v_4',
#  '024v_1',
#  '029r_1',
#  '029v_1',
#  '029v_6',
#  '031r_1',
#  '032v_1',
#  '033r_1',
#  '033v_2',
#  '035v_1',
#  '035v_2',
#  '036r_1',
#  '036v_3',
#  '037r_2',
#  '037v_1',
#  '038r_2',
#  '038r_4',
#  '038v_2',
#  '038v_5',
#  '038v_6',
#  '039r_2',
#  '039v_3',
#  '040r_1',
#  '041r_04',
#  '041v_3',
#  '042v_1',
#  '042v_5',
#  '042v_6',
#  '043v_1',
#  '044r_5',
#  '044v_2',
#  '044v_3',
#  '046r_1',
#  '046r_2',
#  '046r_3',
#  '046r_4',
#  '047r_1',
#  '047r_3',
#  '047r_5',
#  '048r_3',
#  '049r_2',
#  '049r_3',
#  '050r_1',
#  '050v_1',
#  '051r_1',
#  '051r_2',
#  '052r_1',
#  '053v_1',
#  '055r_3',
#  '055v_2',
#  '056r_1',
#  '056r_2',
#  '056v_1',
#  '057v_1',
#  '057v_2',
#  '058v_1',
#  '058v_4',
#  '058v_5',
#  '059r_2',
#  '060r_3',
#  '060v_3',
#  '063r_1',
#  '063r_2',
#  '063v_1',
#  '063v_3',
#  '063v_4',
#  '064r_2',
#  '065r_1',
#  '066r_3',
#  '066v_1',
#  '066v_2',
#  '067r_1',
#  '067r_4',
#  '067v_3',
#  '069r_2',
#  '071r_2',
#  '071r_3',
#  '071v_1',
#  '072r_2',
#  '073r_3',
#  '073r_4',
#  '073v_1',
#  '073v_2',
#  '073v_3',
#  '074r_3',
#  '075v_2',
#  '075v_4',
#  '076r_3',
#  '076r_5',
#  '076v_1',
#  '077r_2',
#  '077v_1',
#  '077v_2',
#  '077v_3',
#  '078r_1',
#  '079v_1',
#  '081v_3',
#  '081v_4',
#  '083r_3',
#  '083v_2',
#  '084v_1',
#  '084v_2',
#  '084v_4',
#  '085v_4',
#  '087v_2',
#  '088r_5',
#  '088v_2',
#  '089v_1',
#  '089v_2',
#  '090v_2',
#  '091r_2',
#  '093r_1',
#  '094r_1',
#  '096v_3',
#  '097v_1',
#  '098r_1',
#  '098r_2',
#  '098r_3',
#  '098v_2',
#  '100r_1',
#  '100v_2',
#  '101v_3',
#  '102r_2',
#  '102v_2',
#  '103r_1',
#  '104r_2',
#  '104r_4',
#  '104r_5',
#  '105r_4',
#  '107r_1',
#  '108r_2',
#  '109r_1',
#  '109v_1',
#  '110v_1',
#  '110v_2',
#  '111v_1',
#  '112v_1',
#  '116r_2',
#  '116r_4',
#  '116v_2',
#  '117v_1',
#  '117v_2',
#  '118r_3',
#  '118v_1',
#  '119r_1',
#  '120r_2',
#  '120v_6',
#  '121r_1',
#  '121v_1',
#  '122r_2',
#  '123r_1',
#  '124r_1',
#  '126r_1',
#  '126v_3',
#  '128r_1',
#  '129r_1',
#  '129r_2',
#  '129r_4',
#  '129v_4',
#  '130r_3',
#  '130r_4',
#  '134v_3',
#  '135r_1',
#  '135r_3',
#  '135v_1',
#  '138v_2',
#  '138v_3',
#  '139r_1',
#  '139v_1',
#  '141r_1',
#  '142v_1',
#  '143r_1',
#  '143v_3',
#  '144r_1',
#  '145v_1',
#  '147v_4',
#  '148r_1',
#  '149v_3',
#  '151v_1',
#  '152r_1',
#  '153r_2',
#  '154v_4',
#  '154v_5',
#  '155r_1',
#  '155v_1',
#  '156v_1',
#  '158r_1',
#  '158v_1',
#  '159v_2',
#  '162v_2',
#  '163r_1',
#  '164r_2',
#  '169r_1',
#  '170v_2',
#  '170v_3']

# %% [markdown]
# We can also search based on specific properties. The terms to be searched for, even if there is only one, must be written in a list.

# %%
rose_entries = manuscript.search(plant=['rose'])
rose_entries
# Out:
# ['010r_1',
#  '010r_3',
#  '116r_4',
#  '120v_6',
#  '129r_4',
#  '154v_4',
#  '155r_1',
#  '155v_1',
#  '159v_2',
#  '169r_1']

# %%
iron_water_entries = manuscript.search(material=['iron', 'water'])
iron_water_entries
# Out:
# ['001v_1',
#  '003r_1',
#  '003r_3',
#  '003v_1',
#  '004r_2',
#  '004v_1',
#  '004v_3',
#  '005r_1',
#  '005v_1',
#  '006r_1',
#  '006v_2',
#  '007r_1',
#  '007v_3',
#  '008v_2',
#  '008v_5',
#  '010r_5',
#  '010v_1',
#  '010v_3',
#  '010v_4',
#  '011r_1',
#  '011v_1',
#  '012r_1',
#  '012r_4',
#  '012v_3',
#  '013v_2',
#  '015v_4',
#  '016r_1',
#  '016v_1',
#  '017r_1',
#  '020v_1',
#  '021r_2',
#  '022v_1',
#  '023r_1',
#  '023v_1',
#  '024v_1',
#  '028v_1',
#  '029r_1',
#  '029v_2',
#  '029v_6',
#  '030r_2',
#  '031r_2',
#  '031r_3',
#  '032r_3',
#  '032v_3',
#  '035r_2',
#  '035r_3',
#  '036v_3',
#  '037r_3',
#  '037r_4',
#  '038r_4',
#  '039r_2',
#  '039v_3',
#  '040r_2',
#  '040r_3',
#  '041v_3',
#  '042r_2',
#  '042v_1',
#  '042v_2',
#  '042v_3',
#  '043v_1',
#  '044v_2',
#  '046r_1',
#  '047r_1',
#  '047v_1',
#  '048v_1',
#  '048v_2',
#  '049r_1',
#  '049v_2',
#  '050r_1',
#  '050v_2',
#  '051r_1',
#  '051r_2',
#  '052r_1',
#  '052v_2',
#  '053r_2',
#  '053r_4',
#  '053v_1',
#  '055v_1',
#  '055v_2',
#  '055v_3',
#  '055v_4',
#  '056r_1',
#  '056v_1',
#  '057v_1',
#  '057v_2',
#  '058v_4',
#  '058v_5',
#  '059r_2',
#  '060r_3',
#  '060v_2',
#  '061v_1',
#  '061v_3',
#  '062v_1',
#  '063r_3',
#  '063r_6',
#  '063v_3',
#  '064r_3',
#  '064r_4',
#  '065r_4',
#  '065v_6',
#  '066r_3',
#  '066r_6',
#  '066v_4',
#  '067v_1',
#  '067v_3',
#  '068r_3',
#  '072r_2',
#  '072v_1',
#  '073r_1',
#  '073r_2',
#  '073r_3',
#  '073r_4',
#  '073r_5',
#  '074r_1',
#  '074v_1',
#  '074v_2',
#  '075r_2',
#  '075r_3',
#  '075v_1',
#  '075v_3',
#  '076v_4',
#  '077r_4',
#  '078r_2',
#  '078v_1',
#  '078v_4',
#  '079r_2',
#  '080r_3',
#  '081r_3',
#  '081r_4',
#  '081v_2',
#  '081v_4',
#  '082r_2',
#  '082v_4',
#  '083v_1',
#  '084v_2',
#  '084v_4',
#  '085v_4',
#  '087v_3',
#  '088r_2',
#  '088v_2',
#  '090r_3',
#  '090v_1',
#  '092r_2',
#  '092v_2',
#  '093r_1',
#  '093v_2',
#  '094r_1',
#  '097r_2',
#  '097v_1',
#  '098r_2',
#  '098r_3',
#  '098v_5',
#  '100v_1',
#  '101r_1',
#  '102v_2',
#  '103r_1',
#  '103r_2',
#  '103v_5',
#  '104r_2',
#  '104v_2',
#  '105v_2',
#  '105v_4',
#  '106r_2',
#  '106v_1',
#  '106v_2',
#  '107r_1',
#  '108r_2',
#  '109r_3',
#  '110r_2',
#  '110v_1',
#  '110v_2',
#  '111r_4',
#  '111v_1',
#  '111v_5',
#  '112r_1',
#  '112v_1',
#  '113r_1',
#  '114r_1',
#  '115r_1',
#  '116r_2',
#  '116v_2',
#  '117r_1',
#  '117v_4',
#  '118r_5',
#  '118v_1',
#  '119v_1',
#  '',
#  '121r_1',
#  '121v_1',
#  '124r_3',
#  '124v_2',
#  '125r_1',
#  '125r_2',
#  '125v_3',
#  '126r_1',
#  '126v_3',
#  '128v_1',
#  '129v_1',
#  '131r_5',
#  '131v_1',
#  '133r_3',
#  '134r_1',
#  '134v_3',
#  '135v_1',
#  '136v_1',
#  '137r_1',
#  '137r_2',
#  '137v_1',
#  '139r_1',
#  '139v_1',
#  '141r_1',
#  '143r_1',
#  '143r_2',
#  '143v_2',
#  '144r_1',
#  '145v_1',
#  '146v_1',
#  '147v_4',
#  '148r_1',
#  '148r_2',
#  '148r_4',
#  '149r_1',
#  '149r_3',
#  '150v_1',
#  '151v_1',
#  '152r_1',
#  '152v_1',
#  '153r_1',
#  '153r_2',
#  '154v_3',
#  '155r_1',
#  '155v_1',
#  '156v_1',
#  '157v_3',
#  '159r_1',
#  '159v_4',
#  '160r_1',
#  '160r_2',
#  '160v_1',
#  '161r_1',
#  '161v_1',
#  '163r_2',
#  '163v_2',
#  '164v_2',
#  '165r_2',
#  '165v_1',
#  '167r_1',
#  '169r_1',
#  '170v_2']

# %%
iron_water_rose = manuscript.search(material=['iron', 'water'], plant=['rose'], tool=True)
iron_water_rose
# Out:
# ['155r_1', '155v_1', '169r_1']

# %% [markdown]
# This list of identities can be converted into a manuscript object containing only the entries found in the list by passing the list as a parameter into a new object.

# %%
rose_manuscript = BnF(rose_entries)

# %%
for identity, entry in rose_manuscript.entries.items():
    print(identity, entry.title['tl'])
# Out:
# 010r_1 Counterfeit jasper
# 010r_3 Roses
# 116r_4 A way to grind enamel gold very delicate gold rose leaves and others
# 120v_6 Keeping dry flowers in the same state all year
# 129r_4 Molded roses
# 154v_4 Reinforcing flowers and delicate things
# 155r_1 Molding a rose
# 155v_1 Rose
# 159v_2 Carnation
# 169r_1 [List of processes]

# %% [markdown]
# ## Custom Data

# %% [markdown]
# Let's take this reduced manuscript, and generate a data table representing its contents. One advantage of using Jupyter Notebook is that it allows us to import open source packages on a browser without downloading them to a machine. Pandas allows us to easily generate, manipulate, and save spreadsheets, or DataFrames.

# %%
df = rose_manuscript.tablefy()
df
# Out:
#                                    entry folio folio_display  div_id  \
# 0  <recipe.Recipe object at 0x11a604150>  010r           10r  010r_1
# 1  <recipe.Recipe object at 0x11a609a10>  010r           10r  010r_3
# 2  <recipe.Recipe object at 0x11af12350>  116r          116r  116r_4
# 3  <recipe.Recipe object at 0x11af79650>  120v          120v  120v_6
# 4  <recipe.Recipe object at 0x11b024190>  129r          129r  129r_4
# 5  <recipe.Recipe object at 0x11b1d9a50>  154v          154v  154v_4
# 6  <recipe.Recipe object at 0x11b1e3650>  155r          155r  155r_1
# 7  <recipe.Recipe object at 0x11b1eb710>  155v          155v  155v_1
# 8  <recipe.Recipe object at 0x11b238c10>  159v          159v  159v_2
# 9  <recipe.Recipe object at 0x11b2f2cd0>  169r          169r  169r_1
#
#           categories                                         heading_tc  \
# 0  stones;decorative                                  Jaspe contrefaict
# 1         decorative                                              Roses
# 2      metal process  Moyen desmouailler desmailler des foeilles dor...
# 3         preserving  Garder fleurs seiches en mesme  estat toute la...
# 4            casting                                      Roses moulees
# 5            casting           Renforcer les fleurs et choses delicates
# 6            casting                                    Mouler une rose
# 7            casting                                               Rose
# 8            casting                                            Oeillet
# 9              lists                                [Liste de procédés]
#
#                                          heading_tcn  \
# 0                                  Jaspe contrefaict
# 1                                              Roses
# 2  Moyen desmouailler d’esmailler des foeilles do...
# 3  Garder fleurs seiches en mesme  estat toute l’...
# 4                                      Roses moulées
# 5           Renforcer les fleurs et choses delicates
# 6                                    Mouler une rose
# 7                                               Rose
# 8                                            Oeillet
# 9                                [Liste de procédés]
#
#                                           heading_tl  margins  \
# 0                                 Counterfeit jasper        3
# 1                                              Roses        3
# 2  A way to grind enamel gold very delicate gold ...        3
# 3     Keeping dry flowers in the same state all year        3
# 4                                       Molded roses        3
# 5            Reinforcing flowers and delicate things        3
# 6                                     Molding a rose        3
# 7                                               Rose        3
# 8                                          Carnation        3
# 9                                [List of processes]        3
#
#                                             del_tags  ...  \
# 0                                               horn  ...
# 1                                             <ill/>  ...
# 2               grind; gold; <fr>uy</fr>; <fr>d</fr>  ...
# 3  <fr>ce</fr>; use; <fr>v</fr>; <fr>Que</fr>; w;...  ...
# 4                                       <fr>obl</fr>  ...
# 5                             &amp;; delicate things  ...
# 6  <fr>aupart</fr>; <fr>en</fr>; of; <fr>be</fr>;...  ...
# 7               <fr>b</fr>; it; <fr>esb</fr>; of the  ...
# 8                                                     ...
# 9                                      <fr>P</fr>; p  ...
#
#                                          measurement music  \
# 0
# 1
# 2
# 3  quand leur saison passe; horologe de sable; pl...
# 4
# 5
# 6
# 7
# 8
# 9
#
#                                                plant place personal_name  \
# 0                                       roses; aspic
# 1                                              roses
# 2                                        rose; roses
# 3  pensees; amaranthe; palta lupina; genest; rose...
# 4                   roses; pensees; froment; caprier
# 5                             roses; pensee; froment
# 6                   rose; fraisiers; rosier; rosiers
# 7                                               rose
# 8                              rose; soulcy; oeillet
# 9  rose; mousses; vigne; capilli veneris; froment...
#
#            profession sensory  \
# 0
# 1
# 2
# 3  verriers; orfevres
# 4
# 5
# 6
# 7
# 8
# 9
#
#                                                 tool  \
# 0                                       rabot; limer
# 1
# 2
# 3  doibs; boicte; linge; tamis; horologe de sable...
# 4
# 5                                      petit pinceau
# 6             filets; moules; moule; cercle dardille
# 7  tige de fil de letton; clou; petite poincte de...
# 8                                              moule
# 9                                    filets; chassis
#
#                                                 time weapon
# 0
# 1
# 2
# 3  hors de saison quand lhiver desnie des fleurs;...
# 4
# 5
# 6                                         long temps
# 7
# 8
# 9
#
# [10 rows x 28 columns]

# %% [markdown]
# New, custom columns can be added by creating a function that defines this property given an entry object as an input.

# %%
def foo(entry):
    return 'foo ' + entry.identity

# %%
def first_word_tl(entry):
    return entry.text('tl', xml=False).strip().split(' ')[0]

# %%
df['foo'] = df.entry.apply(lambda x: foo(x))
df['first_word'] = df.entry.apply(lambda x: first_word_tl(x))
df
# Out:
#                                    entry folio folio_display  div_id  \
# 0  <recipe.Recipe object at 0x11a604150>  010r           10r  010r_1
# 1  <recipe.Recipe object at 0x11a609a10>  010r           10r  010r_3
# 2  <recipe.Recipe object at 0x11af12350>  116r          116r  116r_4
# 3  <recipe.Recipe object at 0x11af79650>  120v          120v  120v_6
# 4  <recipe.Recipe object at 0x11b024190>  129r          129r  129r_4
# 5  <recipe.Recipe object at 0x11b1d9a50>  154v          154v  154v_4
# 6  <recipe.Recipe object at 0x11b1e3650>  155r          155r  155r_1
# 7  <recipe.Recipe object at 0x11b1eb710>  155v          155v  155v_1
# 8  <recipe.Recipe object at 0x11b238c10>  159v          159v  159v_2
# 9  <recipe.Recipe object at 0x11b2f2cd0>  169r          169r  169r_1
#
#           categories                                         heading_tc  \
# 0  stones;decorative                                  Jaspe contrefaict
# 1         decorative                                              Roses
# 2      metal process  Moyen desmouailler desmailler des foeilles dor...
# 3         preserving  Garder fleurs seiches en mesme  estat toute la...
# 4            casting                                      Roses moulees
# 5            casting           Renforcer les fleurs et choses delicates
# 6            casting                                    Mouler une rose
# 7            casting                                               Rose
# 8            casting                                            Oeillet
# 9              lists                                [Liste de procédés]
#
#                                          heading_tcn  \
# 0                                  Jaspe contrefaict
# 1                                              Roses
# 2  Moyen desmouailler d’esmailler des foeilles do...
# 3  Garder fleurs seiches en mesme  estat toute l’...
# 4                                      Roses moulées
# 5           Renforcer les fleurs et choses delicates
# 6                                    Mouler une rose
# 7                                               Rose
# 8                                            Oeillet
# 9                                [Liste de procédés]
#
#                                           heading_tl  margins  \
# 0                                 Counterfeit jasper        3
# 1                                              Roses        3
# 2  A way to grind enamel gold very delicate gold ...        3
# 3     Keeping dry flowers in the same state all year        3
# 4                                       Molded roses        3
# 5            Reinforcing flowers and delicate things        3
# 6                                     Molding a rose        3
# 7                                               Rose        3
# 8                                          Carnation        3
# 9                                [List of processes]        3
#
#                                             del_tags  ...  \
# 0                                               horn  ...
# 1                                             <ill/>  ...
# 2               grind; gold; <fr>uy</fr>; <fr>d</fr>  ...
# 3  <fr>ce</fr>; use; <fr>v</fr>; <fr>Que</fr>; w;...  ...
# 4                                       <fr>obl</fr>  ...
# 5                             &amp;; delicate things  ...
# 6  <fr>aupart</fr>; <fr>en</fr>; of; <fr>be</fr>;...  ...
# 7               <fr>b</fr>; it; <fr>esb</fr>; of the  ...
# 8                                                     ...
# 9                                      <fr>P</fr>; p  ...
#
#                                                plant place personal_name  \
# 0                                       roses; aspic
# 1                                              roses
# 2                                        rose; roses
# 3  pensees; amaranthe; palta lupina; genest; rose...
# 4                   roses; pensees; froment; caprier
# 5                             roses; pensee; froment
# 6                   rose; fraisiers; rosier; rosiers
# 7                                               rose
# 8                              rose; soulcy; oeillet
# 9  rose; mousses; vigne; capilli veneris; froment...
#
#            profession sensory  \
# 0
# 1
# 2
# 3  verriers; orfevres
# 4
# 5
# 6
# 7
# 8
# 9
#
#                                                 tool  \
# 0                                       rabot; limer
# 1
# 2
# 3  doibs; boicte; linge; tamis; horologe de sable...
# 4
# 5                                      petit pinceau
# 6             filets; moules; moule; cercle dardille
# 7  tige de fil de letton; clou; petite poincte de...
# 8                                              moule
# 9                                    filets; chassis
#
#                                                 time weapon         foo  \
# 0                                                            foo 010r_1
# 1                                                            foo 010r_3
# 2                                                            foo 116r_4
# 3  hors de saison quand lhiver desnie des fleurs;...         foo 120v_6
# 4                                                            foo 129r_4
# 5                                                            foo 154v_4
# 6                                         long temps         foo 155r_1
# 7                                                            foo 155v_1
# 8                                                            foo 159v_2
# 9                                                            foo 169r_1
#
#         first_word
# 0      Counterfeit
# 1   Roses\n\nThese
# 2                A
# 3          Keeping
# 4           Molded
# 5      Reinforcing
# 6          Molding
# 7  Rose\n\nBecause
# 8  Carnation\n\nIt
# 9             List
#
# [10 rows x 30 columns]

# %% [markdown]
# Pandas can handle much of the difficult file processing required to save this data. With the two lines below, we can drop the column that represents the memory address of the recipe object, and convert the DataFrame to .csv format. If `df.to_csv()` were run in an executable function fromn the command line, the file will be saved in the current working directory.

# %%
df = df.drop(columns=['entry'])
df.to_csv(index=False)
# Out:
# 'folio,folio_display,div_id,categories,heading_tc,heading_tcn,heading_tl,margins,del_tags,figures,animal,body_part,currency,definition,environment,material,medical,measurement,music,plant,place,personal_name,profession,sensory,tool,time,weapon,foo,first_word\n010r,10r,010r_1,stones;decorative,Jaspe contrefaict,Jaspe contrefaict,Counterfeit jasper,3,horn,unknown,,,,,,jaspe; gomme armoniac; jaspe contrefaict; roses; colle forte; vinaigre; or &amp; argent en foeille; verre; huile daspic; corne; limaille de talc ou despingle; vernis daspic; pierres; jaspe grumeleux; laines a gros poil; huiler; argent; foeille destaing; tourmentine claire; cornalines; ciment; tourmentine,,,,roses; aspic,,,,,rabot; limer,,,foo 010r_1,Counterfeit\n010r,10r,010r_3,decorative,Roses,Roses,Roses,3,<ill/>,unknown,,,,,,corne de lanternes; parchemin,,,,roses,,,,,,,,foo 010r_3,"Roses\n\nThese"\n116r,116r,116r_4,metal process,Moyen desmouailler desmailler des foeilles dore roses dor fort subtilles et aultres,Moyen desmouailler d’esmailler des foeilles dore roses d’or fort subtilles et aultres,A way to grind enamel gold very delicate gold rose leaves and others,3,grind; gold; <fr>uy</fr>; <fr>d</fr>,unknown,,,,,,eau dfort; argent; lames dargent; ciment real; esmail; esmailler; souldes; or; esmaillee,,,,rose; roses,,,,,,,,foo 116r_4,A\n120v,120v,120v_6,preserving,Garder fleurs seiches en mesme  estat toute lannee,Garder fleurs seiches en mesme  estat toute l’année,Keeping dry flowers in the same state all year,3,<fr>ce</fr>; use; <fr>v</fr>; <fr>Que</fr>; w; too; so that; on; e; half; l,unknown,,doibs; main; poin,,,cabinets; chambres; soleil; au soleil; soleil chault; serain &amp; humeur de la nuit; temps de pluye et humide; lieu sec; courant des eaulx,vinaigre distille; poulsiere; sable le plus maigre &amp; aride que tu pourras trouver; cire; bled; linge; sable de quoy les orfevres usent les esmaulx; esmail; poil de cheval; sable; sable maigre; sable de riviere; mastic; poulssiere; resideure du vinaigre commun,,quand leur saison passe; horologe de sable; plusieurs jours,,pensees; amaranthe; palta lupina; genest; roses; oeillets; soulcis; boufains; fleurs jaulnes; ranunculus,,,verriers; orfevres,,doibs; boicte; linge; tamis; horologe de sable; vase bien selle; poin; grands vases; pinceau,hors de saison quand lhiver desnie des fleurs; saison; toute lannee; plusieurs jours,,foo 120v_6,Keeping\n129r,129r,129r_4,casting,Roses moulees,Roses moulées,Molded roses,3,<fr>obl</fr>,unknown,mouches,,,,,sable destrempe; huile de froment,,,,roses; pensees; froment; caprier,,,,,,,,foo 129r_4,Molded\n154v,154v,154v_4,casting,Renforcer les fleurs et choses delicates,Renforcer les fleurs et choses delicates,Reinforcing flowers and delicate things,3,&amp;; delicate things,unknown,mouche,,,,,beurre fondu; huile de froment,,,,roses; pensee; froment,,,,,petit pinceau,,,foo 154v_4,Reinforcing\n155r,155r,155r_1,casting,Mouler une rose,Mouler une rose,Molding a rose,3,<fr>aupart</fr>; <fr>en</fr>; of; <fr>be</fr>; them; All; until; <fr>Aulcu</fr>,unknown,,alheine,,,,cendre; cire; souldure; sable destrempe; letton estame; ardille; terre; eau; sable; beurre fondu; estain; plomb; eau de vye; huiler,,,,rose; fraisiers; rosier; rosiers,,,,,filets; moules; moule; cercle dardille,long temps,,foo 155r_1,Molding\n155v,155v,155v_1,casting,Rose,Rose,Rose,3,<fr>b</fr>; it; <fr>esb</fr>; of the,unknown,mouche; poisson,,,,,ceruse bien broyee; argent; colle de poisson; colle; cire esb a esbaucher; soulde; or; soulder; metaulx; estain; cire blanche; fil de letton; blanc de plomb; fer,,,,rose,,,,,tige de fil de letton; clou; petite poincte de fer chaulde; moules; petites poinctes,,,foo 155v_1,"Rose\n\nBecause"\n159v,159v,159v_2,casting,Oeillet,Oeillet,Carnation,3,,unknown,,,,,,souldure; sable fort cler,,,,rose; soulcy; oeillet,,,,,moule,,,foo 159v_2,"Carnation\n\nIt"\n169r,169r,169r_1,lists,[Liste de procédés],[Liste de procédés],[List of processes],3,<fr>P</fr>; p,unknown,oiseaulx; cef volant; papillo ...
