# %%
import os
import pandas as pd
import nltk
wn = nltk.corpus.wordnet
from digital_manuscript import BnF

# %%
term = 'physical_entity'
dog = wn.synsets(term, pos=wn.NOUN)
dog[0].hypernyms()
# hyper = dog[0].hypernyms()
# for x in hyper:
#     print(x, x.hypernyms())

# from nltk.corpus import wordnet as wn
# for ss in wn.synsets(term):
#     print (ss, ss.hypernyms())
# Out:
# [Synset('entity.n.01')]

# %%
animal = wn.synset('animal.n.01')
artifact = wn.synset('artifact.n.01')

class r_node:
    def __init__(self, lemma, children=[]):
        self.lemma = lemma
        
#         if lemma == animal:
#             print(children + [lemma,])
        self.children = children
        self.hypernyms = lemma.hypernyms()
        self.parents = [r_node(h, children + [lemma,]) for h in self.hypernyms]
        
    def return_animal_path(self):
        if self.lemma == wn.synset('animal.n.01'):
            return [[self.lemma,],]
        else:
            parent_paths = [n.return_animal_path() for n in self.parents]
            parent_paths = [p for p in parent_paths if len(p) > 0]
            paths = []
            for p in parent_paths:
                paths += p
            for p in paths:
                p.append(self.lemma)
            return paths

    def return_concept_path(self):
        if self.lemma == wn.synset('entity.n.01'):
            return [[self.lemma,],]
        else:
            parent_paths = [n.return_concept_path() for n in self.parents]
            parent_paths = [p for p in parent_paths if len(p) > 0]
            paths = []
            for p in parent_paths:
                paths += p
            for p in paths:
                p.append(self.lemma)
            return paths

# %%
dog = wn.synsets('cloth', pos=wn.NOUN)[0]
dn = r_node(dog)
dn.return_concept_path()
# print([p.parents[0].lemma for p in dn.parents])

# animal
# Out:
# [[Synset('entity.n.01'),
#   Synset('physical_entity.n.01'),
#   Synset('object.n.01'),
#   Synset('whole.n.02'),
#   Synset('artifact.n.01'),
#   Synset('fabric.n.01')]]

# %%
squirrel = wn.synsets('squirrel')[0]
sn = r_node(squirrel)
sn.return_animal_path()
# Out:
# [[Synset('animal.n.01'),
#   Synset('chordate.n.01'),
#   Synset('vertebrate.n.01'),
#   Synset('mammal.n.01'),
#   Synset('placental.n.01'),
#   Synset('rodent.n.01'),
#   Synset('squirrel.n.01')]]

# %%
fish = wn.synsets('fish', pos=wn.NOUN)[0]
fn = r_node(fish)
fn.return_animal_path()
# Out:
# [[Synset('animal.n.01'),
#   Synset('chordate.n.01'),
#   Synset('vertebrate.n.01'),
#   Synset('aquatic_vertebrate.n.01'),
#   Synset('fish.n.01')]]

# %%
louse = wn.synsets('louse')[0]
ln = r_node(louse)
ln.return_animal_path()
# Out:
# [[Synset('animal.n.01'),
#   Synset('invertebrate.n.01'),
#   Synset('arthropod.n.01'),
#   Synset('insect.n.01'),
#   Synset('louse.n.01')]]

# %%
oyster = wn.synsets('oyster')[0]
on = r_node(oyster)
on.return_animal_path()
# Out:
# [[Synset('animal.n.01'),
#   Synset('invertebrate.n.01'),
#   Synset('mollusk.n.01'),
#   Synset('bivalve.n.01'),
#   Synset('oyster.n.01')]]

# %%
squirrel = wn.synsets('squirrel')[0]
weasel = wn.synsets('weasel')[1] # index 0 is a sneaky person
squirrel.lowest_common_hypernyms(weasel)

snake = wn.synsets('snake')[0]
print(snake.lowest_common_hypernyms(weasel))
print(snake.lowest_common_hypernyms(squirrel))

turtle = wn.synsets('turtle')[1] # index 0 is a turtleneck (lmao)
print(turtle.lowest_common_hypernyms(snake))
print(turtle.lowest_common_hypernyms(squirrel))

fish = wn.synsets('fish', pos=wn.NOUN)[0] # pos = part of speech
swan = wn.synsets('swan')[0]
print(fish.lowest_common_hypernyms(turtle))
print(fish.lowest_common_hypernyms(snake))

louse = wn.synsets('louse')[0]
oyster = wn.synsets('oyster')[0]
print(louse.lowest_common_hypernyms(snake))
print(louse.lowest_common_hypernyms(oyster))
# Out:
# [Synset('vertebrate.n.01')]
# [Synset('vertebrate.n.01')]
# [Synset('reptile.n.01')]
# [Synset('vertebrate.n.01')]
# [Synset('vertebrate.n.01')]
# [Synset('vertebrate.n.01')]
# [Synset('animal.n.01')]
# [Synset('invertebrate.n.01')]

# %%
path = os.getcwd() + '/../manuscript-object/thesaurus/animal.csv'

df = pd.read_csv(path)
terms = list(set(df['prefLabel_en']))
simple_terms = [t for t in terms if ' ' not in t]
simple_terms


for i in range(len(simple_terms)) :
    if simple_terms[i] in ['weasel','turtle','cuckoo','codfish','mussel','chicken','goldfinch','turtledofe','linnet', 'water-dog']: #first meaning is not the animal. Birds tend to have another bird as first meaning
        if simple_terms[i]=='turtledofe':
            simple_terms[i]='turtledove'
        elif simple_terms[i]=='water-dog':
            simple_terms[i]='water_dog'
        lit = [simple_terms[i],1]
    elif simple_terms[i] in ['ewe','swallow','crayfish','partridge','hart',"calendra",'calandra','hog']:#have to go to third meaning to get the animal or the right bird
        if simple_terms[i] in ["calendra",'calandra']:
            simple_terms[i]='lark'
        lit = [simple_terms[i],2]
    elif simple_terms[i] in ['dragon']:#the mythical creature does not have a link to animal. This is "any of several small tropical Asian lizards capable of gliding by spreading winglike membranes on each side of the body"
        lit = [simple_terms[i],3]
    else :
        lit = [simple_terms[i],0]
    simple_terms[i]=lit

for i in range(len(simple_terms)):
    word=simple_terms[i][0]
    liste = wn.synsets(word,pos=wn.NOUN)
    for item in liste:
        ani = r_node(item)
        if ani.return_animal_path()!=[]:
            simple_terms[i].append(item.definition())
        else : 
            simple_terms[i].append(item.definition() + " (not in tree)")

# %%
df = pd.DataFrame(simple_terms)
#df.to_csv('./simple_terms.csv',sep=',',index=False)

# %%
class Node(object):

    def __init__(self, value, parent):
        self.value = value
        self.children = []
        if parent is not None:
            parent.children.append(self)

# %%
from print_tree import print_tree   #actually using package print-tree2 from pypi

class print_custom_tree(print_tree):

    def get_children(self, node):
        return node.children

    def get_node_str(self, node):
        return str(node.value)

# %%
animaln = Node('animal', None)
visited = []
skipped=0
path = os.getcwd() + '/../manuscript-object/simple_terms.csv'
words = pd.read_csv(path)

for animals in words.itertuples() :
    if animals[1] not in ['bombicum','og','verdaule','tellin','petit-gri','aucupio','daot','shell','mutton','barbel','pork']:   #not in wordnet or not in tree
        ani = wn.synsets(animals[1])[animals[2]]
        an = r_node(ani)
        lis = an.return_animal_path()[0]
        for i in range (1,len(lis)):
            name = lis[i].name().split('.')[0]
            if name in ['even-toed_ungulate','odd-toed_ungulate','orthopterous_insect','chordate','placental','ungulate','thrush','oscine','leporid','lagomorph','decapod_crustacean','chordate','diapsid','anapsid','chelonian','bovid','bovine',"anseriform_bird",'wading_bird','columbiform_bird','corvine_bird','cuculiform_bird','aquatic_vertebrate','bony_fish','teleost_fish','gadoid','ganoid','annelid','oligochaete','decapod','soft-finned_fish','phasianid','ambystomid','red_deer','hominid','agamid', 'sporting_dog']: #- make everything go boom also things I don't care about
                skipped+=1
                visited.append(name)
            elif name not in visited :
                name_prec = lis[i-1-skipped].name().split('.')[0]
                skipped=0
                string = name+'n'+' = Node(name,'+ name_prec+'n)'
                exec(string)
                visited.append(name)
            else :
                skipped=0

print_custom_tree(animaln)
# Out:
#                                   ┌musteline_mammal─weasel
#                                   │      ┌wolf
#                         ┌carnivore┼canine┤
#                         │         │      └dog─hunting_dog─water_dog
#                         │         └feline─cat
#                         │      ┌squirrel
#                         │      ├dormouse
#                         ├rodent┼mouse
#                         │      ├rat
#                         │      └porcupine
#                         ├swine─hog
#                         │      ┌horse
#                         ├equine┤
#                         │      └mule
#                  ┌mammal┤
#                  │      ├primate─homo
#                  │      │        ┌sheep─ewe
#                  │      │        │      ┌cow
#                  │      │        ├cattle┼beef
#                  │      │        │      └ox
#                  │      ├ruminant┤
#                  │      │        ├goat
#                  │      │        └deer─hart
#                  │      ├bat
#                  │      └rabbit
#                  │                 ┌waterfowl─duck
#                  │    ┌aquatic_bird┼swan
#                  │    │            └heron─bittern
#                  │    │         ┌lark
#                  │    │         ├new_world_oriole─meadowlark
#                  │    │         │     ┌linnet
#                  │    │         │     ├chaffinch
#                  │    │         ├finch┼goldfinch
#                  │    │         │     ├siskin
#                  │    │         │     └bunting─ortolan
#                  │    ├passerine┤
#                  │    │         ├crow
#                  │    │         ├nightingale
#                  │    │         └swallow
#                  ├bird┼bird_of_prey─eagle
#                  │    │                 ┌game_bird─partridge
#                  │    │                 │                     ┌hen
#                  │    ├gallinaceous_bird┼domestic_fowl─chicken┤
#                  │    │                 │                     └chick
#                  │    │                 └pigeon─dove─turtledove
#                  │    └cuckoo
#                  │    ┌cod
#       ┌vertebrate┼fish┤
#       │          │    └bowfin
#       │          │       ┌snake─viper
#       │          ├reptile┼turtle
#       │          │       └saurian─lizard─dragon
#       │          └amphibian─frog
#       │     ┌mealworm
#       ├larva┤
#       │     └caterpillar─silkworm
# animal┤
#       │                    ┌cephalopod─cuttlefish
#       │            ┌mollusk┼gastropod─snail
#       │            │       │       ┌oyster
#       │            │       └bivalve┤
#       │            │               └mussel
#       │            │                ┌lepidopterous_insect─butterfly
#       │            │                ├flea
#       │            │                ├homopterous_insect─cicada
#       │            │         ┌insect┼louse
#       │            │         │      ├grasshopper
#       │            │         │      ├hymenopterous_insect─ant
#       │            │         │      └dipterous_insect─fly
#       ├invertebrate┼arthropod┼arachnid─spider
#       │            │         │          ┌crayfish
#       │            │         └crustacean┤
#       │            │                    └crab
#       │            └worm─earthworm
#       │                  ┌calf
#       └young─young_mammal┼lamb
#                          └foal─colt

# %%
path = os.getcwd() + '/../manuscript-object/thesaurus/material.csv'

df = pd.read_csv(path)
terms = list(set(df['prefLabel_en']))
terms.pop(0)
simple_terms = [t for t in terms if ' ' not in t]
simple_terms
# Out:
# ['verjuice',
#  'rosemary',
#  'pansy',
#  'couleur',
#  'straw',
#  'alabaster',
#  'seed',
#  'bone',
#  'dough',
#  'jet',
#  'enilanroc',
#  'mud',
#  'earthworm',
#  'acetum',
#  'air',
#  'asphaltum',
#  'paint',
#  'stone',
#  'ember',
#  'brouillamini',
#  'ferri',
#  'wool',
#  'letter',
#  'silvered',
#  'quarton',
#  'eau-de-vie',
#  'vermillion',
#  'slate',
#  'thread',
#  'tin',
#  'cinnabar',
#  'iron',
#  'verdet',
#  'dirt',
#  'mineral',
#  'card',
#  'rapeseed',
#  'solfo',
#  'grinding',
#  'fat',
#  'otnegra',
#  'antho',
#  'colla',
#  'mercury',
#  'string',
#  'silver',
#  'bullitoyre',
#  'drug',
#  'cord',
#  'ore',
#  'jasper',
#  'linen',
#  'sandalwood',
#  'azure',
#  'massicot',
#  'thunderstone',
#  'talcum',
#  'wine',
#  'galipot',
#  'incense',
#  'bituman',
#  'k',
#  'flour',
#  'mold',
#  'rosette',
#  'onion',
#  'benzoin',
#  'sugar',
#  'pumouse',
#  'syrup',
#  'chestnut',
#  'crust',
#  'center',
#  'sap',
#  'egg',
#  'magistra',
#  'gild',
#  'solle',
#  'calamine',
#  'rocaille',
#  'lye',
#  'sheep',
#  'enamelled',
#  'coppera',
#  'hair',
#  'glass',
#  'flint',
#  'diamond',
#  'grai',
#  'rust',
#  'topaz',
#  'sand',
#  'grè',
#  'cambric',
#  'earwax',
#  'woollen',
#  'dyeing',
#  'leady',
#  'dittany',
#  'garnet',
#  'marrow',
#  'sludge',
#  'ferret-silk',
#  'broth',
#  'orange',
#  'sapphire',
#  'down',
#  'emerald',
#  'nail',
#  'blood',
#  'almond',
#  'pitch',
#  'tile',
#  'lead',
#  'earthen',
#  'tragacanth',
#  'milk',
#  'brick',
#  'coryal',
#  'candle',
#  'gemstone',
#  'sanguine',
#  'unleaded',
#  'sublimate',
#  'blue',
#  'tuf',
#  'wisp',
#  'aquaforti',
#  'bronze',
#  'rue',
#  'quill',
#  'earthenware',
#  'foodstuff',
#  'earth',
#  'residue',
#  'vetro',
#  'verdigri',
#  'flesh',
#  'cardboard',
#  'ocher',
#  'aloe',
#  'luted',
#  'trwood',
#  'clofe',
#  'plate',
#  'husk',
#  '☾',
#  'wooden',
#  'foil',
#  'animal',
#  'filth',
#  'rose',
#  'shell',
#  'chalk',
#  'litharge',
#  'amber',
#  'felt',
#  'fir',
#  'horsetail',
#  'glueing',
#  'stucco',
#  'purpurina',
#  'tow',
#  'gilded',
#  'skin',
#  'vitriol',
#  'plaster',
#  'quicksilver',
#  'touchstone',
#  'shale',
#  'crayon',
#  'rainwater',
#  'white',
#  'garlic',
#  'grain',
#  'tisane',
#  'persicaire',
#  'tint',
#  'crimson',
#  'bloodstone',
#  'aquamarine',
#  'mortar',
#  'glued',
#  'steel',
#  'jelly',
#  '☼',
#  'solder',
#  'cristallin',
#  'oiled',
#  'civet',
#  'grime',
#  'germ',
#  'wallwort',
#  'luting',
#  'dyed',
#  'niello',
#  'madder',
#  'mushroom',
#  'spirit',
#  'florey',
#  'willow',
#  'vermilion',
#  'latten',
#  'maple',
#  'stavesacre',
#  'cloth',
#  'boxwood',
#  'oil',
#  'orpiment',
#  'brine',
#  'spider',
#  'rock',
#  'heather',
#  'dust',
#  'phlegm',
#  'ceruse',
#  'ferlin',
#  'tincture',
#  'lard',
#  'verd',
#  'prele',
#  'tallow',
#  'metal',
#  'toadstone',
#  'varnish',
#  'hay',
#  'marcasite',
#  'tinning',
#  'soot',
#  'elm',
#  'umber',
#  'soldered',
#  'carton',
#  'ivory',
#  'jacinth',
#  'honey',
#  'potin',
#  'felinder',
#  'lucertum',
#  'filing',
#  'electrum',
#  'brazilwood',
#  'cornaline',
#  'regulu',
#  'putty',
#  'realgar',
#  'quicklime',
#  'glair',
#  'aurea',
#  'bran',
#  'stuf',
#  'sheet',
#  'hazelnut',
#  'bile',
#  'saliva',
#  'leaded',
#  'smoke',
#  'grease',
#  'soap',
#  'arum',
#  'pebble',
#  'clay',
#  'foam',
#  'enameled',
#  'resin',
#  'parchment',
#  'ruby',
#  'ash',
#  'flower',
#  'cement',
#  'paste',
#  'horsedung',
#  'barley',
#  'arène',
#  'vernice',
#  'distemper',
#  '☉',
#  'bread',
#  'arrabeic',
#  'ardide',
#  'amalgam',
#  'floret',
#  'maplewood',
#  'starch',
#  'incarnadine',
#  'vermiculari',
#  'chimolée',
#  'wood',
#  'powder',
#  'gold',
#  'porfidio',
#  'flin',
#  'ebony',
#  'saltwort',
#  'sorrel',
#  'metalline',
#  'dye',
#  'black',
#  'musk',
#  'bole',
#  'lake',
#  'pearl',
#  'beef',
#  '☿',
#  'horn',
#  'porkfat',
#  'salted',
#  'preserf',
#  'sol',
#  'purple',
#  'tinned',
#  'tripoli',
#  'tinsel',
#  'columbine',
#  'sumac',
#  'storax',
#  'plant',
#  'lampblack',
#  'sulfur',
#  'silk',
#  'debri',
#  'stagno',
#  'borax',
#  'theriac',
#  'charcoaled',
#  'enamelling',
#  '☀',
#  'canva',
#  'yolk',
#  'aspalte',
#  'lute',
#  'glue',
#  'saffron',
#  'firestone',
#  'zedoary',
#  'magnet',
#  'perfume',
#  'amethyst',
#  'crystal',
#  'walnut',
#  'cochineal',
#  'sandiver',
#  'cocon',
#  'feather',
#  'cocon.',
#  'piss',
#  'urine',
#  'millet',
#  'mastic',
#  'rosin',
#  'taffeta',
#  '♀',
#  'soldering',
#  'nastiness',
#  'vinegar',
#  'enamel',
#  'metallic',
#  'cheese',
#  'manganese',
#  'ball',
#  'aspalt',
#  'juice',
#  'buckram',
#  'cinnamon',
#  'real',
#  'arsenic',
#  'oiling',
#  'ironware',
#  'gilding',
#  'charcoal',
#  'bronzing',
#  'eggshell',
#  'wadding',
#  'crêpe',
#  'crocum',
#  'pearled',
#  'lime',
#  'muddying',
#  'spalt',
#  'satin',
#  'billon',
#  'horsehair',
#  'sandarac',
#  'enameling',
#  'minium',
#  'food',
#  'gum',
#  'cork',
#  'felin',
#  'bullitoire',
#  'rowan,',
#  'wire',
#  'fenugreek',
#  'mealworm',
#  'pith',
#  'basan',
#  'manure',
#  'wheat',
#  'ammoniac',
#  'bistre',
#  'soil',
#  'antimony',
#  'tartar',
#  'opiate',
#  'sap-green',
#  'copper',
#  'milla',
#  'saltwater',
#  'coral',
#  'slaver',
#  'pulverin',
#  'waxed',
#  'porphyry',
#  'plumb',
#  'goumiche',
#  'emery',
#  'spat',
#  'smoked',
#  'alum',
#  'turpentine',
#  'pea',
#  'rutum',
#  'cornflower',
#  'wax',
#  'gravel',
#  'ambergri',
#  'cendrée',
#  'colophony',
#  'taffer',
#  'fruit',
#  'cotton',
#  'salty',
#  'fume',
#  'camphor',
#  'batture',
#  'water',
#  'marble',
#  'rye',
#  'gilt',
#  'taffetum',
#  'damascening',
#  'fresil',
#  'puffball',
#  'impurity',
#  'mustard',
#  'arabic',
#  'arene',
#  'fustet',
#  'scale',
#  'oily',
#  'ink',
#  'dung',
#  'isinglass',
#  'beryl',
#  'whitening',
#  'velvet',
#  'butter',
#  'melli',
#  'leather',
#  'agate',
#  'saltpeter',
#  'or',
#  'wicker',
#  'vermeille',
#  'bean',
#  'mine',
#  'paper',
#  'nailhead',
#  'ointment',
#  'salpeter',
#  'rooftile',
#  'ferro',
#  'weld',
#  'salt',
#  'aceto']

# %%
entityn = Node('entity', None)
visited = []
skipped=0

for material in simple_terms :
    if material not in ['☉','☾','☼','☀','glueing','coryal','incarnadine','flin','spalt', 'crimson','grai','aquaforti','colla','vetro', 'goumiche', 'vermilion','arene', 'theriac', 'bituman', 'aceto', 'wooden','zedoary','stagno','basan','rowan,','antho','☿','waxed','toadstone','glair','purple', 'sandiver','fustet','potin','dyeing','taffetum','bullitoyre','ferro','canva','touchstone','tinning','muddying','ferlin','nastiness','leaded','arabic','salted','soldering','lucertum','soldered','gild','glued','rooftile','earthen','milla','metalline','ambergri','stavesacre','bullitoire','couleur','arrabeic','charcoaled','cendrée','cristallin','porfidio','dyed','ferri','smoked','maplewood','arène','vernice','brouillamini','whitening','real','salpeter','k','♀','bronzing','azure','preserf','thunderstone','clofe','litharge','purpurina','tow','salty','felin','tinned','prele','crocum','tint','verdigri','silvered','pumouse','fremouse','fresil','verdet','oiled','horsedung','cocon.','billon','tuf','vermiculari','pulverin','grime','unleaded','solle','felinder','coppera','quarton','batture','eau-de-vie','florey','taffer','wallwort','enameled','ferret-silk','ardide','porkfat','sanguine','magistra','vermeille','cornaline','niello','enamelling','cocon','aspalt','damascening','melli','grè','rocaille','crêpe','aurea','aspalte','solfo','chimolée','enamelled','sap-green','rutum','trwood','stuf','leady','debri','luted','galipot','vermillion','enameling','pearled','persicaire','enilanroc','oiling','otnegra','marcasite','oily','verjuice','gilded','verd','asphaltum','regulu']:   #not in wordnet or not in entity tree
        if material in ['earth','soil','lead','filing','spat','ocher','perfume','mold','wisp','coral','germ','phlegm','foam','or','ebony','amber','carton','blue']:
            ani = wn.synsets(material, pos=wn.NOUN)[1]
        elif material in['pitch','distemper','gold']:
            ani = wn.synsets(material, pos=wn.NOUN)[2]
        elif material in ['scale']:
            ani = wn.synsets(material, pos=wn.NOUN)[3]
        elif material in ['black']:
            ani = wn.synsets(material, pos=wn.NOUN)[4]
        else :
            ani = wn.synsets(material, pos=wn.NOUN)[0]
        an = r_node(ani)
        lis = an.return_concept_path()[0]
        for i in range (1,len(lis)):
            name = lis[i].name().split('.')[0]
            if name in ['even-toed_ungulate', 'high-angle_gun','copper-base_alloy','ovum',"dyer's_rocket",'edible_fat','heavier-than-air_craft','reproductive_structure','legging','consumer_goods','ceramic_ware','source_of_illumination','baseball_equipment','hospital_room','sheet_metal','vascular_plant','vertebrate','mammal','placental','plant_product','animal_tissue']: #- make everything go boom also things I don't care about
                skipped+=1
                visited.append(name)
            elif name not in visited :
                name_prec = lis[i-1-skipped].name().split('.')[0]
                skipped=0
                string = name+'n'+' = Node(name,'+ name_prec+'n)'
                exec(string)
                visited.append(name)
            else :
                skipped=0

print_custom_tree(entityn)
# Out:
#                                                                     ┌rosemary
#                                                                     ├viola─pansy
#                                                                     ├fraxinella
#                                                                     ├rue
#                                                                ┌herb┼oxalis
#                                                                │    │                             ┌millet
#                                                                │    ├gramineous_plant─grass─cereal┤
#                                                                │    │                             └wheat
#                                                                │    ├fenugreek
#                                                                │    ├crucifer─mustard
#                                                                │    └reseda
#                                                                │                                   ┌fruit_tree─almond_tree─almond
#                                                                │                ┌angiospermous_tree┤
#                                                                │                │                  └nut_tree─hazelnut
#                                                                │           ┌tree┼willow
#                                                                │           │    └elm
#                                                                ├woody_plant┤
#                                                                │           │     ┌rose
#                                                                │           └shrub┼heath─heather
#                                                                │                 └saltwort
#                                                                ├succulent─aloe
#                                                          ┌plant┤
#                                                          │     ├pteridophyte─fern_ally─horsetail
#                                                          │     │             ┌liliaceous_plant─alliaceous_plant─garlic
#                                                          │     ├bulbous_plant┤
#                                                          │     │             └iridaceous_plant─crocus─saffron
#                                                          │     │                        ┌madderwort─madder
#                                                          │     └spermatophyte─angiosperm┤
#                                                          │                              │      ┌floret
#                                                          │                              └flower┼columbine
#                                                          │                                     └bellwort─strawflower
#                                                          │                   ┌worm─annelid─oligochaete─earthworm
#                                                          │      ┌invertebrate┤
#                                                          │      │            └arthropod─arachnid─spider
#                                                          │      │                                ┌sheep
#                                                          │      │        ┌ungulate─ruminant─bovid┤
#                                                          │      │        │                       └bovine─cattle─beef
#                                                 ┌organism┼animal┼chordate┤
#                                                 │        │      │        └carnivore─viverrine─civet
#                                                 │        │      └larva─mealworm
#                                                 │        │      ┌basidiomycete─agaric─mushroom
#                                                 │        └fungus┤
#                                                 │               └puffball
#                                    ┌living_thing┤
#                                    │            └cell─reproductive_cell─gamete─egg
#                                    │                                                ┌oilseed─rapeseed
#                                    │                                           ┌seed┤
#                                    │                                           │    └nut─edible_nut─walnut
#                                    │                                     ┌fruit┤
#                                    │                                     │     └edible_fruit─citrus─orange
#                                    │                         ┌plant_organ┼stalk─bulb─onion
#                                    │                         │           └leaf─scale
#                                    │              ┌plant_part┤
#                                    │              │          └plant_tissue─pith
#                              ┌whole┼natural_object┤
#                              │     │              │    ┌sedimentary_rock─shale
#                              │     │              │    ├pebble
#                              │     │              │    ├limestone─rottenstone
#                              │     │              └rock┤
#                              │     │                   ├igneous_rock─porphyry
#                              │     │                   ├gravel
#                              │     │                   └marble
#                              │     │                        ┌conveyance─vehicle─craft─aircraft─airplane─jet
#                              │     │                        │         ┌mold
#                              │     │                        ├container┤
#                              │     │                        │         └box─carton
#                              │     │                        │      ┌lamp─candle
#                              │     │                        ├device┼noisemaker─horn
#                              │     │                        │      └magnet
#                              │     │                        │                           ┌pen─quill
#                              │     │                        │         ┌writing_implement┤
#                              │     │                        │         │                 └crayon
#                              │     │                        ├implement┤
#                              │     │                        │         └utensil─earthenware
#                              │     │                        │         ┌sports_equipment─base─home_plate
#                              │     │        ┌instrumentality┼equipment┤
#                              │     │        │               │         └game_equipment─ball
#                              │     │        │               │        ┌ammunition─shell
#                              │     │        │               ├weaponry┤
#                              │     │        │               │        └armament─artillery─cannon─mortar
#                              │     │        │               ├toiletry─perfume
#                              │     │        │               ├hardware
#                              │     │        │               └connection─attachment─ligament─wire
#                              │     │        │                ┌paint─distemper
#                              │     │        │        ┌coating┼varnish
#                              │     │        │        │       └gilt
#                              │     │        │        │             ┌hair
#                              │     │        ├covering┼body_covering┤
#                              │     │        │        │             └skin
#                              │     │        │        │    ┌cinnamon
#                              │     │        │        └bark┤
#                              │     │        │             └cork
#                              │     │        │      ┌wool
#                              │     │        │      ├linen
#                              │     │        │      ├cambric
#                              │     │        │      ├felt
#                              │     │        │      ├silk
#                              │     │        ├fabric┤
#                              │     │        │      ├taffeta
#                              │     │        │      ├metallic
#                              │     │        │      ├buckram
#                              │     │        │      ├satin
#                              │     │        │      └velvet
#                              │     │        ├creation─representation─document─letter
#                              │     │        │          ┌tablet─slate
#                              │     │        ├block─slab┤
#                              │     │        │          └tile
#                              │     │        │         ┌thread
#                              │     │        ├line─cord┤
#                              │     │        │         └string
#                              │     └artifact┤
#                              │              │                    ┌rosette
#                              │              │          ┌adornment┤
#                              │              │          │         │             ┌diamond
#                              │              │          │         └jewelry─jewel┼ruby
#                              │              │          │                       └pearl
#                              │              ├decoration┼tinsel
#                              │              │          └nailhead
#                              │              │                 ┌brick
#                              │              ├building_material┼covering_material─plaster─stucco
#                              │              │                 └concrete
#                              │              │                  ┌blue
#                              │              │         ┌clothing┤
#                              │              │         │        └garment─spat
#                              │              ├commodity┤
#                              │              │         └grocery
#                              │              ├sheet─foil
#                              │              ├weight─bob─plumb_bob
#                              │              └excavation─mine
#                       ┌object┤
#                       │      │               ┌layer─crust
#                       │      │        ┌region┤
#                       │      │        │      │    ┌center
#                       │      │        │      └area┤
#                       │      │        │           └room─operating_room
#                       │      └location┤
#                       │               └point─position─pitch
#                       │                                                         ┌straw
#                       │                         ┌fiber─natural_fiber─plant_fiber┤
#                       │                         │                               └cotton
#                       │                         │                      ┌calcium_sulphate─gypsum─alabaster
#                       │                         │                 ┌salt┤
#                       │                         │                 │    └cream_of_tartar
#                       │                         │                 │    ┌carboxylic_acid─acetic_acid─acetum
#                       │                         │                 ├acid┤
#                       │                         │                 │    └vitriol
#                       │                         │                 ├incense
#                       │                         │                 ├caustic─lye
#                       │                         │                 │     ┌silica─flint─firestone
#                       │                         │                 │     ├ferric_oxide─rust
#                       │                         │                 ├oxide┼calcium_oxide
#                       │                         │                 │     ├trioxide─arsenic
#                       │                         │                 │     └red_lead
#                       │                         │        ┌compound┤
#                       │                         │        │        │                     ┌fresh_water─rain
#                       │                         │        │        ├binary_compound─water┤
#                       │                         │        │        │                     └seawater
#                       │                         │        │        ├formulation─cleansing_agent─soap
#                       │                         │        │        ├organic_compound─resin
#                       │                         │        │        ├hydroxide─calcium_hydroxide
#                       │                         │        │        └nitrate─potassium_nitrate
#                       │                         ├chemical┤
#                       │                         │        └fertilizer─organic─manure
#                       │                         │          ┌mud
#                       │                         ├earth─soil┼sand
#                       │                         │          └clay
#                       │                         │       ┌cinnabar
#                       │                         │       ├ore─lead_ore─massicot
#                       │                         │       ├talc
#                       │                         │       ├hemimorphite
#                       │                         │       │      ┌topaz
#                       │                         │       │      │          ┌bloodstone
#                       │                         │       ├quartz┼chalcedony┤
#                       │                         │       │      │          └agate
#                       │                         │       │      └amethyst
#                       │                         │       ├garnet
#                       │                         │       ├corundom─sapphire
#                       │                         │       │     ┌emerald
#                       │                         │       ├beryl┤
#                       │                         │       │     └aquamarine
#                       │                         ├mineral┤
#                       │                         │       │           ┌ocher
#                       │                         │       ├earth_color┤
#                       │                         │       │           └umber
#                       │                         │       ├spar─calcite─chalk
#                       │                         │       ├orpiment
#                       │                         │       ├zircon─hyacinth
#                       │                         │       ├realgar
#                       │                         │       ├borax
#                       │                         │       ├emery
#                       │                         │       └mica
#                       │                         │     ┌card
#                       │                         ├paper┤
#                       │                         │     └parchment
#                       │                         │    ┌grinding
#                       │                         ├atom┤
#                       │                         │    │     ┌barley
#                       │                         │    └grain┤
#                       │                         │          └rye
#                       │                         │         ┌silver
#                       │                         ├conductor┤
#                       │                         │         └copper
#                       │                         │                   ┌sandalwood
#                       │                         │                   ├chestnut
#                       │                         │                   ├fir
#                       │                         │                   ├maple
#                       │                         │                   ├boxwood
#                       │                         │              ┌wood┤
#                       │                         │              │    ├brazilwood
#                       │                         │              │    ├ebony
#                       │                         │              │    ├sumac
#                       │                         │              │    ├sandarac
#                       │                         │              │    └wicker
#                       │                         │              │             ┌gum_resin─benzoin
#                       │                         │              │             ├amber
#                       │                         │              │             ├storax
#                       │                         ├plant_material┼natural_resin┼mastic
#                       │                         │              │             ├oleoresin─turpentine
#                       │                         │              │             ├colophony
#                       │                         │              │             └camphor
#                       │                         │              └chaff─bran
#                       │                         │               ┌feather─down
#                       │                         │               ├animal_oil─tallow
#                       │                ┌material┼animal_material┤
#                       │                │        │               ├dentine─ivory
#                       │                │        │               │              ┌animal_fiber─horsehair
#                       │                │        │               └animal_product┤
#                       │                │        │                              └animal_skin─leather
#                       │                │        │                     ┌tragacanth
#                       │                │        ├discharge─exudate─gum┤
#                       │                │        │                     └ammoniac
#                       │                │        ├packing_material─cardboard
#                       │                │        │     ┌filth
#                       │                │        │     │          ┌urine
#                       │                │        ├waste┼body_waste┤
#                       │                │        │     │          └fecal_matter─droppings
#                       │                │        │     └impurity
#                       │                │        ├sealing_material─lute
#                       │                │        ├particulate─dust
#                       │                │        │                         ┌white_lead
#                       │                │        │                 ┌pigment┼bole
#                       │                │        │                 │       └bister
#                       │                │        ├coloring_material┼tincture
#                       │                │        │                 └dye─cochineal
#                       │                │        │                        ┌putty
#                       │                │        ├adhesive_material─cement┤
#                       │                │        │                        └glue
#                       │                │        └foam
#                       │                │              ┌concoction─dough
#                       │                │              ├flour
#                       │                │    ┌foodstuff┤
#                       │                │    │         │                              ┌sugar
#                       │                │    │         │                   ┌sweetening┼syrup
#                       │                │    │         │                   │          └honey
#                       │                │    │         │          ┌flavorer┤
#                       │                │    │         │          │        └condiment─vinegar
#                       │                │    │         ├ingredient┤
#                       │                │    │         │          └egg_yolk
#                       │                │    │         │             ┌cheese
#                       │                │    │         └dairy_product┤
#                       │                │    │                       └butter
#                       │                │    │        ┌alcohol─wine
#                       │                │    ├beverage┼milk
#                       │                │    │        └tea─herb_tea─tisane
#                       │                │    │         ┌dish─soup─broth
#                       │                │    ├nutriment┤
#                       │                │    │         │      ┌gelatin
#                       │                │    │         └dainty┤
#                       │                │    │                └sweet─chewing_gum
#                       │                ├food┤
#                       │                │    ├feed─fodder─hay
#                       │                │    ├baked_goods─bread
#                       │                │    │                        ┌pea
#                       │                │    └produce─vegetable─legume┤
#                       │                │                             └bean
#                       │                │                                 ┌tin
#                       │                │                                 ├iron
#                       │                │                                 ├mercury
#                       │                │                                 ├lead
#                       │                │                ┌metallic_element┤
#                       │                │                │                ├noble_metal─gold
#                       │                │                │                ├manganese
#                       │                │                │                ├antimony
#                       │                │                │                └aluminum─alum
#                       │                │                │      ┌carbon_black
#                       │      ┌substance┼chemical_element┼carbon┤
#                       │      │         │                │      └charcoal
#                       │      │         │                └sulfur
#                       │      │         │       ┌solution─sap
#                       │      │         │       │     ┌bronze
#                       │      │         │       │     ├steel
#                       │      │         │       │     ├solder
#                       │      │         │       ├alloy┤
#                       │      │         │       │     ├brass─latten
#                       │      │         │       │     ├electrum
#                       │      │         │       │     └amalgam
#                       │      │         ├mixture┤
#                       │      │         │       ├composition─paste
#                       │      │         │       └colloid─sol
#                       │      │         │                                    ┌blood
#                       │      │         │                                    │         ┌mucus─phlegm
#                       │      │         │              ┌liquid_body_substance┼secretion┼saliva
#                       │      │         │              │                     │         └musk
#                       │      │         │              │                     └juice─digestive_juice─bile
#                       │      │         └body_substance┤
#                       │      │                        └solid_body_substance─enamel
#                       │      │         ┌air
#                       │      │     ┌gas┤
#                       │      │     │   └sublimate
#                       │      ├fluid┤
#                       │      │     └liquid─ink
#                       ├matter┤
#                       │      │                            ┌jasper
#                       │      │     ┌crystal─gem─opaque_gem┤
#                       │      │     │                      └coral
#                       │      │     ├glass
#                       │      ├solid┤
#                       │      │     ├precipitate─sludge
#                       │      │     └powder
#                       │      └residue─ash
#                       │                                             ┌bone
#                       │                           ┌connective_tissue┤
#                       │                           │                 └marrow
#                       │                    ┌tissue┤
#                       │                    │      └flesh
#                       │          ┌body_part┤
#                       │          │         │         ┌horny_structure─nail
#                       │          │         └structure┼germ
#                       │          │                   └building_complex
#                       │     ┌part┤
#                       │     │    │        ┌ember
#                       │     │    └fragment┤
#                       │     │             └filing
#                       │     │                                 ┌fat─lard
#                       │     │                           ┌lipid┼wax─cerumen
#                       │     │                           │     └oil─grease
#       ┌physical_entity┼thing┼unit─molecule─macromolecule┤
#       │               │     │                           └carbohydrate─polysaccharide─starch─arum
#       │               │     └body_of_water─lake
#       │               │                       ┌narcotic─opiate
#       │               │            ┌agent─drug┤
#       │               │            │          └medicine─remedy─ointment
#       │               │            │      ┌small_person─wisp
#       │               │            │      ├white
#       │               ├causal_agent┼person┤
#       │               │            │      ├black
#       │               │            │      └bad_person─victimizer─slaver
#       │               │            └vital_principle─spirit
#       │               └process─phenomenon─natural_phenomenon─physical_phenomenon─cloud─aerosol─smoke
# entity┤
#       └abstraction─attribute─shape─amorphous_shape─space─expanse
